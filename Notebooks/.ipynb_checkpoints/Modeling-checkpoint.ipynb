# %% [markdown]
# # Louis George
#
# ## Modeling

# %% [markdown]
# Format of this notebook:
#  - main sections will be exploring the different results for the various targets
#  - each of these sections will include a LR, and XGB model for both TFIDF, and LDA
#  - Therefore as of now, there will be a total of 4 models for each target, with associated results (feature importance, and scores)
#  - scratch that, no LDA - will simply look at TFIDF, and maybe look at more models - LR, DT, BNB, XBG

# %% [markdown]
# The Gain implies the relative contribution of the corresponding feature to the model calculated by taking each feature’s contribution for each tree in the model. A higher value of this metric when compared to another feature implies it is more important for generating a prediction.
#
# https://towardsdatascience.com/be-careful-when-interpreting-your-features-importance-in-xgboost-6e16132588e7

# %%
import numpy as np
import pandas as pd

from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.decomposition import LatentDirichletAllocation


from xgboost import XGBClassifier, plot_importance

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
plt.rc('ytick', labelsize=15)

# %% [markdown]
# ### Reading in the data

# %%
X_train_tfidf = pd.read_csv('../../data/X_train_tfidf.csv')
X_test_tfidf = pd.read_csv('../../data/X_test_tfidf.csv')

# %%
X_train_countv = pd.read_csv('../../data/X_train_countv.csv')
X_test_countv = pd.read_csv('../../data/X_test_countv.csv')

# %%
y_imdb_train = pd.read_csv('../../data/y_imdb_train.csv')
y_rt_train = pd.read_csv('../../data/y_rt_train.csv')
y_profit_train = pd.read_csv('../../data/y_profit_train.csv')

y_imdb_test = pd.read_csv('../../data/y_imdb_test.csv')
y_rt_test = pd.read_csv('../../data/y_rt_test.csv')
y_profit_test = pd.read_csv('../../data/y_profit_test.csv')

# %% [markdown]
# ### Exploring the possibility of using LDA Decomposition

# %%
topic_num = [3, 5, 10, 20]

train_scores = []
test_scores = []

for i in topic_num:
    lda = LatentDirichletAllocation(n_components=i).fit(X_train_countv)
    lda_train_weights = lda.transform(X_train_countv)
    lda_test_weights = lda.transform(X_test_countv)
    logreg = LogisticRegression().fit(lda_train_weights, y_imdb_train)
    train_scores.append(logreg.score(lda_train_weights, y_imdb_train))
    test_scores.append(logreg.score(lda_test_weights, y_imdb_test))

# %%
plt.figure(figsize=(10, 7))
plt.plot(topic_num, train_scores, marker='.', label='train')
plt.plot(topic_num, test_scores, marker='.', label='test')
plt.legend()

# %% [markdown]
# As we can see from this graph, LDA decomposition is not going to give us any good results. For fun, let's see what the topics look like for one of the more reasonable results:

# %%
# Function which shows the features with the highest coefficients for each topic
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic #%d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()

# This function is courtesy of the sklearn documentation @:
# https://scikit-learn.org/stable/auto_examples/applications/plot_topics_extraction_with_nmf_lda.html#sphx-glr-auto-examples-applications-plot-topics-extraction-with-nmf-lda-py

# %%
topic_num = 5

lda = LatentDirichletAllocation(n_components=topic_num).fit(X_train_countv)

lda_train_weights = lda.transform(X_train_countv)
lda_test_weights = lda.transform(X_test_countv)

n_top_words = 20
feature_names = X_train_countv.columns

print_top_words(lda, feature_names, n_top_words)
# Out:
# Topic #0: Horror genre comedy SciFi sci sci fi fi Comedy scary genre comedy horror peg Family wednesday movie Musical ha ha worth Fantasy cube
# Topic #1: Horror genre comedy SciFi sci sci fi fi Comedy scary genre comedy horror peg Family wednesday movie Musical ha ha worth Fantasy cube
# Topic #2: Num_NOUN Num_VERB Num_PROPN Num_ADJ Num_ADV gun guard cont'd blood ship angle Num_PRON soldier tree horse draw captain father control sir
# Topic #3: Num_NOUN Num_PROPN Num_VERB Num_ADJ Num_ADV jack yeah cont'd to guy sam frank phone okay Num_PRON paul go to charlie mr john
# Topic #4: Num_PROPN Num_NOUN Num_VERB Num_ADJ Num_ADV cont'd george david max mr harry mark phone office v.o mary bob scott tony eddie

# %% [markdown]
# Here we see that it's mainly picking up on the engineered features containing the count of different parts of speech for each script, and also the genres.
#
# Moving forward, we'll focus on tf-idf.

# %% [markdown]
# ### IMDb Score Models

# %% [markdown]
# TFIDF

# %%
logreg = LogisticRegression().fit(X_train_tfidf, y_imdb_train)

print(f'IMDB train score: {logreg.score(X_train_tfidf, y_imdb_train)}')
print(f'IMDB test score: {logreg.score(X_test_tfidf, y_imdb_test)}')
# Out:
# IMDB train score: 0.7380607814761215
# IMDB test score: 0.645021645021645

# %%
lr_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':logreg.coef_[0]})
lr_t10 = lr_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(lr_t10['Coef'], abs(lr_t10['Value']))
plt.title("Features with the Highest Coefficient \n Logistic Regression")
plt.xlabel("Coefficient Value")
plt.show();

# %%
xgbc = XGBClassifier().fit(X_train_tfidf, y_imdb_train)

print(f'IMDB train score: {xgbc.score(X_train_tfidf, y_imdb_train)}')
print(f'IMDB test score: {xgbc.score(X_test_tfidf, y_imdb_test)}')
# Out:
# IMDB train score: 1.0
# IMDB test score: 0.5974025974025974

# %%
xg_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':xgbc.feature_importances_})
xg_t10 = xg_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(xg_t10['Coef'], abs(xg_t10['Value']))
plt.title("Features with the Highest Gain \n XG Boost")
plt.xlabel("Gain")
plt.show();

# %% [markdown]
# ### RT Score Models

# %% [markdown]
# TFIDF

# %%
logreg = LogisticRegression().fit(X_train_tfidf, y_rt_train)

print(f'IMDB train score: {logreg.score(X_train_tfidf, y_rt_train)}')
print(f'IMDB test score: {logreg.score(X_test_tfidf, y_rt_test)}')
# Out:
# IMDB train score: 0.7872648335745297
# IMDB test score: 0.5541125541125541

# %%
lr_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':logreg.coef_[0]})
lr_t10 = lr_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(lr_t10['Coef'], abs(lr_t10['Value']))
plt.title("Features with the Highest Coefficient \n Logistic Regression")
plt.xlabel("Coefficient Value")
plt.show();

# %%
xgbc = XGBClassifier().fit(X_train_tfidf, y_rt_train)

print(f'IMDB train score: {xgbc.score(X_train_tfidf, y_rt_train)}')
print(f'IMDB test score: {xgbc.score(X_test_tfidf, y_rt_test)}')
# Out:
# IMDB train score: 1.0
# IMDB test score: 0.6233766233766234

# %%
xg_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':xgbc.feature_importances_})
xg_t10 = xg_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(xg_t10['Coef'], abs(xg_t10['Value']))
plt.title("Features with the Highest Gain \n XG Boost")
plt.xlabel("Gain")
plt.show();

# %% [markdown]
# ### Profit Models

# %%
logreg = LogisticRegression().fit(X_train_tfidf, y_profit_train)

print(f'IMDB train score: {logreg.score(X_train_tfidf, y_profit_train)}')
print(f'IMDB test score: {logreg.score(X_test_tfidf, y_profit_test)}')
# Out:
# IMDB train score: 0.7395079594790159
# IMDB test score: 0.5497835497835498

# %%
lr_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':logreg.coef_[0]})
lr_t10 = lr_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(lr_t10['Coef'], abs(lr_t10['Value']))
plt.title("Features with the Highest Coefficient \n Logistic Regression")
plt.xlabel("Coefficient Value")
plt.show();

# %%
xgbc = XGBClassifier().fit(X_train_tfidf, y_profit_train)

print(f'IMDB train score: {xgbc.score(X_train_tfidf, y_profit_train)}')
print(f'IMDB test score: {xgbc.score(X_test_tfidf, y_profit_test)}')
# Out:
# IMDB train score: 1.0
# IMDB test score: 0.6190476190476191

# %%
xg_coefs = pd.DataFrame({'Coef':X_train_tfidf.columns,
                         'Value':xgbc.feature_importances_})
xg_t10 = xg_coefs.sort_values(by='Value', ascending=False).head(10)

plt.figure(figsize=(12,7))
plt.barh(xg_t10['Coef'], abs(xg_t10['Value']))
plt.title("Features with the Highest Gain \n XG Boost")
plt.xlabel("Gain")
plt.show();
